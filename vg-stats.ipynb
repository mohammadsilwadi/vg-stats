# %% [markdown]
# # vg -stats note book
# # Mohammad Silwadi
# # 10/25/2021

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('./vgsales.csv')
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# 1- Which company is the most common video game publisher?

# %%
most_common_publisher=df['Publisher'].mode()[0]
most_common_publisher
# Out:
# 'Electronic Arts'

# %% [markdown]
# 2- What’s the most common platform?

# %%
most_common_platform=df['Platform'].value_counts().idxmax()
most_common_platform
# Out:
# 'DS'

# %% [markdown]
# 3-What about the most common genre?

# %%
most_common_genre=df['Genre'].value_counts().idxmax()
most_common_genre
# Out:
# 'Action'

# %% [markdown]
# 4- What are the top 20 highest grossing games?

# %%
df_heighest = df.copy()
most_20_grossing_game=df_heighest[['Rank','Name']].head(20)
most_20_grossing_game
# Out:
#     Rank                                          Name
# 0      1                                    Wii Sports
# 1      2                             Super Mario Bros.
# 2      3                                Mario Kart Wii
# 3      4                             Wii Sports Resort
# 4      5                      Pokemon Red/Pokemon Blue
# 5      6                                        Tetris
# 6      7                         New Super Mario Bros.
# 7      8                                      Wii Play
# 8      9                     New Super Mario Bros. Wii
# 9     10                                     Duck Hunt
# 10    11                                    Nintendogs
# 11    12                                 Mario Kart DS
# 12    13                   Pokemon Gold/Pokemon Silver
# 13    14                                       Wii Fit
# 14    15                                  Wii Fit Plus
# 15    16                            Kinect Adventures!
# ...

# %% [markdown]
# 5-For North American video game sales, what’s the median?

# %%
na_median_sales = df['NA_Sales'].median()
na_median_sales
# Out:
# 0.08

# %% [markdown]
#  ten games surrounding the median sales output

# %%
above = df[df.NA_Sales> na_median_sales].tail(5)
below =df[df.NA_Sales< na_median_sales].head(5)
ten_median_na_seller_names=pd.concat([above,below])
ten_median_na_seller_names
# Out:
#         Rank                                               Name Platform  \
# 10975  10977  Fighting Fantasy: The Warlock of Firetop Mountain       DS
# 10990  10992                                     I Love Puppies       DS
# 10999  11001                            Cake Mania: Main Street       DS
# 11003  11005                                            DaGeDar       DS
# 11012  11014                 NERF N-Strike: Double Blast Bundle      Wii
# 137      138                                  World of Warcraft       PC
# 214      215                           Monster Hunter Freedom 3      PSP
# 338      339                                  Friend Collection       DS
# 348      349                          Pro Evolution Soccer 2008      PS2
# 383      384                                   Monster Hunter 4      3DS
#
#          Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# 10975  2009.0  Role-Playing                         Aspyr      0.09      0.00
# ...

# %% [markdown]
# 6-For the top-selling game of all time, how many standard deviations above/below the mean are its sales for North America?

# %%
zscore = (df.head(1)["NA_Sales"]-df["NA_Sales"].mean())/df['NA_Sales'].std()
zscore
# Out:
# 0    50.478988
# Name: NA_Sales, dtype: float64

# %% [markdown]
# 7-The Nintendo Wii seems to have outdone itself with games. How does its average number of sales compare with all of the other platforms?

# %%
print(df['Global_Sales'].mean())
print(df[df['Platform'] == 'Wii']['Global_Sales'].mean())
# Out:
# 0.5374406555006628
# 0.6994037735849057

# %% [markdown]
# Come up with 3 more questions that can be answered with this data set.
# Q1: what is the date and time of min stop time ?
# Q2: What is the worst selling game? ?
# Q3: what is the median for other sales?

# %%
avg_japan = df['JP_Sales'].mean()
print(avg_japan)
worst_selling = df['Name'][16597]
print(worst_selling)
others_sales_median = df['Other_Sales'].median()
print(others_sales_median)
# Out:
# 0.077781660441017
# Spirits & Spells
# 0.01

# %%
def test():

    def assert_equal(actual,expected):
        assert actual == expected, f"Expected {expected} but got {actual}"

    assert_equal(most_common_publisher,'Electronic Arts')
    assert_equal(most_common_platform,'DS')
    assert_equal(most_common_genre, 'Action')
    assert_equal(most_20_grossing_game.iloc[0].Name, 'Wii Sports')
    assert_equal(most_20_grossing_game.iloc[19].Name, 'Brain Age: Train Your Brain in Minutes a Day')
    assert_equal(na_median_sales, 0.08)
    assert_equal(ten_median_na_seller_names.iloc[1].Name, 'I Love Puppies')

    print("Success!!!")

test()
# Out:
# Success!!!
